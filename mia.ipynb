# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.utils.validation import check_is_fitted
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df=pd.read_csv("shrink_ray_dataset.csv")

# %%
df.shape
# Out:
# (200, 2)

# %%
X=np.array(df["Power"]).reshape(-1,1)
y=np.array(df["Shrinkage"])
y_mean=y.mean()
y_base=[y_mean]*len(y)

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
check_is_fitted(model)

# %%
y_pred=model.predict(X)

# %%
(85-model.intercept_)/model.coef_
# Out:
# array([273.36820555])

# %%
plt.scatter(X,y)
plt.plot(X,y_pred,color="red")
;
# Out:
# ''

# %%
print(mean_absolute_error(y,y_base))
print(mean_absolute_error(y,y_pred))
# Out:
# 24.517993999999998
# 2.558761624732108
